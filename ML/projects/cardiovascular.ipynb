# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn

# %%
df = pd.read_csv("/content/drive/MyDrive/Machine Learning/ML by study mart/12.cardiovascular/cardio_train.csv",sep=';')
df
# Out:
#           id    age  gender  height  weight  ...  gluc  smoke  alco  active  cardio
# 0          0  18393       2     168    62.0  ...     1      0     0       1       0
# 1          1  20228       1     156    85.0  ...     1      0     0       1       1
# 2          2  18857       1     165    64.0  ...     1      0     0       0       1
# 3          3  17623       2     169    82.0  ...     1      0     0       1       1
# 4          4  17474       1     156    56.0  ...     1      0     0       0       0
# ...      ...    ...     ...     ...     ...  ...   ...    ...   ...     ...     ...
# 69995  99993  19240       2     168    76.0  ...     1      1     0       1       0
# 69996  99995  22601       1     158   126.0  ...     2      0     0       1       1
# 69997  99996  19066       2     183   105.0  ...     1      0     1       0       1
# 69998  99998  22431       1     163    72.0  ...     2      0     0       0       1
# 69999  99999  20540       1     170    72.0  ...     1      0     0       1       0
#
# [70000 rows x 13 columns]

# %%
df = df.drop(['id'],axis=1)

# %%
df['cardio'].value_counts()
# Out:
# 0    35021
# 1    34979
# Name: cardio, dtype: int64

# %%
df.isnull().values.any() #checking null values
# Out:
# False

# %%
df.isna().sum() # checking null values in column wise
# Out:
# age            0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
# gluc           0
# smoke          0
# alco           0
# active         0
# cardio         0
# dtype: int64

# %%
seaborn.countplot(df["cardio"])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
seaborn.countplot(x='gender',hue='cardio',data=df,palette='colorblind',edgecolor=seaborn.color_palette('dark',n_colors=1))

# %%
seaborn.countplot(x='age',hue='cardio',data=df,palette='colorblind',edgecolor=seaborn.color_palette('dark',n_colors=1))

# %%
df['yr1']=(df['age']/365).round(0)
df['yr1']
# Out:
# 0        50.0
# 1        55.0
# 2        52.0
# 3        48.0
# 4        48.0
#          ...
# 69995    53.0
# 69996    62.0
# 69997    52.0
# 69998    61.0
# 69999    56.0
# Name: yr1, Length: 70000, dtype: float64

# %%
df['yr']=(df['age']/365).round(0)
df['yr']
# Out:
# 0        50.0
# 1        55.0
# 2        52.0
# 3        48.0
# 4        48.0
#          ...
# 69995    53.0
# 69996    62.0
# 69997    52.0
# 69998    61.0
# 69999    56.0
# Name: yr, Length: 70000, dtype: float64

# %%
seaborn.countplot(x='yr',hue='cardio',data=df,palette='colorblind',edgecolor=seaborn.color_palette('dark',n_colors=1))

# %%
df.describe()
# Out:
#                 age        gender  ...           yr1            yr
# count  70000.000000  70000.000000  ...  70000.000000  70000.000000
# mean   19468.865814      1.349571  ...     53.338686     53.338686
# std     2467.251667      0.476838  ...      6.765294      6.765294
# min    10798.000000      1.000000  ...     30.000000     30.000000
# 25%    17664.000000      1.000000  ...     48.000000     48.000000
# 50%    19703.000000      1.000000  ...     54.000000     54.000000
# 75%    21327.000000      2.000000  ...     58.000000     58.000000
# max    23713.000000      2.000000  ...     65.000000     65.000000
#
# [8 rows x 14 columns]

# %%
df.corr() #corelation
# Out:
#                   age    gender    height  ...    cardio       yr1        yr
# age          1.000000 -0.022811 -0.081515  ...  0.238159  0.999090  0.999090
# gender      -0.022811  1.000000  0.499033  ...  0.008109 -0.023017 -0.023017
# height      -0.081515  0.499033  1.000000  ... -0.010821 -0.081456 -0.081456
# weight       0.053684  0.155406  0.290968  ...  0.181660  0.053661  0.053661
# ap_hi        0.020764  0.006005  0.005488  ...  0.054475  0.020793  0.020793
# ap_lo        0.017647  0.015254  0.006150  ...  0.065719  0.017754  0.017754
# cholesterol  0.154424 -0.035821 -0.050226  ...  0.221147  0.154386  0.154386
# gluc         0.098703 -0.020491 -0.018595  ...  0.089307  0.098596  0.098596
# smoke       -0.047633  0.338135  0.187989  ... -0.015486 -0.047884 -0.047884
# alco        -0.029723  0.170966  0.094419  ... -0.007330 -0.029918 -0.029918
# active      -0.009927  0.005866 -0.006570  ... -0.035653 -0.009819 -0.009819
# cardio       0.238159  0.008109 -0.010821  ...  1.000000  0.237749  0.237749
# yr1          0.999090 -0.023017 -0.081456  ...  0.237749  1.000000  1.000000
# yr           0.999090 -0.023017 -0.081456  ...  0.237749  1.000000  1.000000
#
# [14 rows x 14 columns]

# %%
df = df.drop(['yr1','yr'],axis=1)

# %%
df.describe()
# Out:
#                 age        gender  ...        active        cardio
# count  70000.000000  70000.000000  ...  70000.000000  70000.000000
# mean   19468.865814      1.349571  ...      0.803729      0.499700
# std     2467.251667      0.476838  ...      0.397179      0.500003
# min    10798.000000      1.000000  ...      0.000000      0.000000
# 25%    17664.000000      1.000000  ...      1.000000      0.000000
# 50%    19703.000000      1.000000  ...      1.000000      0.000000
# 75%    21327.000000      2.000000  ...      1.000000      1.000000
# max    23713.000000      2.000000  ...      1.000000      1.000000
#
# [8 rows x 12 columns]

# %%
x = df.iloc[:,:-1]
x
# Out:
#          age  gender  height  weight  ...  gluc  smoke  alco  active
# 0      18393       2     168    62.0  ...     1      0     0       1
# 1      20228       1     156    85.0  ...     1      0     0       1
# 2      18857       1     165    64.0  ...     1      0     0       0
# 3      17623       2     169    82.0  ...     1      0     0       1
# 4      17474       1     156    56.0  ...     1      0     0       0
# ...      ...     ...     ...     ...  ...   ...    ...   ...     ...
# 69995  19240       2     168    76.0  ...     1      1     0       1
# 69996  22601       1     158   126.0  ...     2      0     0       1
# 69997  19066       2     183   105.0  ...     1      0     1       0
# 69998  22431       1     163    72.0  ...     2      0     0       0
# 69999  20540       1     170    72.0  ...     1      0     0       1
#
# [70000 rows x 11 columns]

# %%
y = df.iloc[:,11]
y
# Out:
# 0        0
# 1        1
# 2        1
# 3        1
# 4        0
#         ..
# 69995    0
# 69996    1
# 69997    1
# 69998    1
# 69999    0
# Name: cardio, Length: 70000, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest = train_test_split(x,y,test_size=0.3, random_state=1)

# %%
xtrain
# Out:
#          age  gender  height  weight  ...  gluc  smoke  alco  active
# 23561  16136       2     169    71.0  ...     1      1     0       1
# 34858  14615       1     158    69.0  ...     1      0     0       1
# 54953  20507       1     164    65.0  ...     1      0     0       1
# 59230  16720       1     153    53.0  ...     1      0     0       1
# 1730   21050       1     159    71.0  ...     1      0     0       1
# ...      ...     ...     ...     ...  ...   ...    ...   ...     ...
# 49100  21289       2     175    78.0  ...     1      0     0       1
# 20609  19116       1     164    68.0  ...     1      0     0       0
# 21440  18049       2     178    82.0  ...     1      0     0       1
# 50057  21957       1     169    77.0  ...     1      0     0       0
# 5192   20671       1     174    65.0  ...     2      0     0       1
#
# [49000 rows x 11 columns]

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
Rfc = RandomForestClassifier() # we can also use--> Rfc = RandomForestClassifier( n_estimators=1000)

# %%
Rfc.fit(xtrain,ytrain)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
Rfc.score(xtest,ytest)
# Out:
# 0.7192857142857143

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
Dtc = DecisionTreeClassifier()

# %%
Dtc.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
Dtc.score(xtest,ytest)
# Out:
# 0.6349523809523809
